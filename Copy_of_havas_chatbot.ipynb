# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanth2134567/Vasanth-H/blob/main/Copy_of_havas_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
client = genai.Client(api_key="AIzaSyBlSgtZMQ_pSqJEevD7ZNNoqEnQ3d6Ns9I")

# %%
with open("havas_food_beverage_chatbot_knowledge_database (1).txt","r") as f:
  kb = f.read()

# %%
prompt = f"""
you are HAVAS Customer care executive your job is to provide answers to the questions asked by customers,
you should answer them in polite,if there is any question out of kb say that you did not have the info,only refer the kb and provide te answers

{kb}
"""

# %%
model = 'gemini-2.5-flash'
chat = client.chats.create(
    model=model,
    config={
        'system_instruction':prompt
    }
)

# %%
response = chat.send_message("how the parota is made?")
print(response.text)
# Out:
# I'm sorry, but I don't have information on how specific food items like parotta are made within my knowledge base. I can tell you that we offer parotta as part of our dinner menu!
